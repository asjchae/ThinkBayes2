# %%
import thinkbayes2
import thinkstats2
import thinkplot
import math

# %%
d6 = thinkbayes2.Pmf(range(1,7))

# %%
thinkplot.Hist(d6)

# %%
thinkplot.Hist(d6+d6)

# %%
thinkplot.Hist(d6+d6+d6)

# %%
thinkplot.Hist(d6+d6+d6+d6)

# %%
thinkplot.Hist(d6+d6+d6+d6+d6)

# %%
three_dice = d6+d6+d6
three_dice.Mean()
# Out:
# 10.500000000000002

# %%
three_dice.Var()
# Out:
# 8.75

# %%
math.sqrt(three_dice.Var())
# Out:
# 2.958039891549808

# %%
three_dice.ProbGreater(16)
# Out:
# 0.018518518518518517

# %%
three_dice.Random()
# Out:
# 11

# %%
two = d6 + d6
four = two + two

# %%
thinkplot.Pdfs([d6, two, four])

# %%
three_dice.ProbGreater(9)
# Out:
# 0.625

# %%
# Prior: threedice.ProbGreater(16)
# Data: threedice.ProbGreater(9)

for i in range(3,9):
    three_dice.Remove(i)

# %%
three_dice.Normalize()
# Out:
# 0.7407407407407407

# %%
three_dice.ProbGreater(16)
# Out:
# 0.025

# %%
thinkplot.Hist(three_dice)

# %%
three = two + d6

# What is the best distribution for characteristics of a Dungeons and Dragons character?
for attribute in ('Strength', 'Intelligence', 'Wisdom', 'Dexterity', 'Constitution', 'Charisma'):
    print attribute, three.Random()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72e37f8f0e9e> in <module>()
# ----> 1 three = two + d6
#       2
#       3 # What is the best distribution for characteristics of a Dungeons and Dragons character?
#       4 for attribute in ('Strength', 'Intelligence', 'Wisdom', 'Dexterity', 'Constitution', 'Charisma'):
#       5     print attribute, three.Random()
#
# NameError: name 'two' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b2b5852531eb> in <module>()
# ----> 1 d6 = thinkbayes2.Pmf(range(1,7))
#       2 three = d6+d6+d6
#       3 cdf = three.Max(6)
#       4 thinkplot.Cdf(cdf)
#
# NameError: name 'thinkbayes2' is not defined
